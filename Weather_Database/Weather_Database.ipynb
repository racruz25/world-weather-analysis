# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import linregress
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Current Description": city_desc,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})

    # If an error is experienced, skip the city.
    except Exception as E:
        print(E)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | pangai
# Processing Record 3 of Set 1 | tabialan
# 'coord'
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | songjianghe
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | osterburg
# Processing Record 12 of Set 1 | la crau
# Processing Record 13 of Set 1 | kirkwall
# Processing Record 14 of Set 1 | piacabucu
# Processing Record 15 of Set 1 | coos bay
# Processing Record 16 of Set 1 | salta
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | tuatapere
# Processing Record 20 of Set 1 | valle nacional
# Processing Record 21 of Set 1 | kamien pomorski
# Processing Record 22 of Set 1 | kumbo
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | vaitupu
# 'coord'
# Processing Record 26 of Set 1 | rosita
# Processing Record 27 of Set 1 | taolanaro
# 'coord'
# Processing Record 28 of Set 1 | fairbanks
# Processing Record 29 of Set 1 | golden
# Processing Record 30 of Set 1 | karamea
# 'coord'
# Processing Record 31 of Set 1 | los llanos de aridane
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | krasnoselkup
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | muisne
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | katsuura
# Processing Record 40 of Set 1 | meyungs
# 'coord'
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | jambi
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | saint-francois
# Processing Record 45 of Set 1 | kaeo
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | ketchikan
# Processing Record 48 of Set 1 | edd
# Processing Record 49 of Set 1 | dongsheng
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | saint-joseph
# Processing Record 8 of Set 2 | north platte
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | ratnagiri
# Processing Record 11 of Set 2 | nelson bay
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | qasigiannguit
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | kamenskoye
# 'coord'
# Processing Record 16 of Set 2 | nova soure
# Processing Record 17 of Set 2 | mazagao
# Processing Record 18 of Set 2 | san onofre
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | plouzane
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | hami
# Processing Record 24 of Set 2 | hay river
# Processing Record 25 of Set 2 | hvide sande
# Processing Record 26 of Set 2 | walvis bay
# Processing Record 27 of Set 2 | guapore
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | ostrovnoy
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | gorontalo
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | grand river south east
# 'coord'
# Processing Record 36 of Set 2 | bagan
# Processing Record 37 of Set 2 | san cristobal
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | port blair
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | nalut
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | illoqqortoormiut
# 'coord'
# Processing Record 46 of Set 2 | dolinsk
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | satitoa
# 'coord'
# Processing Record 49 of Set 2 | paamiut
# Processing Record 50 of Set 2 | brazzaville
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | martan-chu
# Processing Record 3 of Set 3 | belaya gora
# Processing Record 4 of Set 3 | dolores hidalgo
# Processing Record 5 of Set 3 | flin flon
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | hovd
# Processing Record 8 of Set 3 | kenai
# Processing Record 9 of Set 3 | pozo colorado
# Processing Record 10 of Set 3 | belushya guba
# 'coord'
# Processing Record 11 of Set 3 | bandarbeyla
# Processing Record 12 of Set 3 | zyryanovsk
# Processing Record 13 of Set 3 | narsaq
# Processing Record 14 of Set 3 | sangar
# Processing Record 15 of Set 3 | poum
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | tselinnoye
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | palabuhanratu
# 'coord'
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | puerto carreno
# Processing Record 24 of Set 3 | amahai
# Processing Record 25 of Set 3 | santiago del estero
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | evans
# Processing Record 29 of Set 3 | rodrigues alves
# Processing Record 30 of Set 3 | autazes
# Processing Record 31 of Set 3 | tezu
# Processing Record 32 of Set 3 | nisia floresta
# Processing Record 33 of Set 3 | hearst
# Processing Record 34 of Set 3 | sobolevo
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | puerto rico
# Processing Record 37 of Set 3 | farah
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | grindavik
# Processing Record 40 of Set 3 | severo-kurilsk
# Processing Record 41 of Set 3 | barentsburg
# 'coord'
# Processing Record 42 of Set 3 | dekar
# Processing Record 43 of Set 3 | krasnyy klyuch
# Processing Record 44 of Set 3 | sampit
# Processing Record 45 of Set 3 | kurtamysh
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | kharan
# Processing Record 49 of Set 3 | sabzevar
# Processing Record 50 of Set 3 | korla
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | umzimvubu
# 'coord'
# Processing Record 3 of Set 4 | the valley
# Processing Record 4 of Set 4 | west plains
# Processing Record 5 of Set 4 | cartagena
# Processing Record 6 of Set 4 | aykhal
# Processing Record 7 of Set 4 | gisborne
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | padang
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | tabiauea
# 'coord'
# Processing Record 13 of Set 4 | liberal
# Processing Record 14 of Set 4 | mount pleasant
# Processing Record 15 of Set 4 | tsihombe
# 'coord'
# Processing Record 16 of Set 4 | nizhneyansk
# 'coord'
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | rocha
# Processing Record 21 of Set 4 | ola
# Processing Record 22 of Set 4 | muros
# Processing Record 23 of Set 4 | marquette
# Processing Record 24 of Set 4 | saleaula
# 'coord'
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | mount gambier
# Processing Record 27 of Set 4 | yakeshi
# Processing Record 28 of Set 4 | bilibino
# Processing Record 29 of Set 4 | mildura
# Processing Record 30 of Set 4 | pochutla
# Processing Record 31 of Set 4 | yumen
# Processing Record 32 of Set 4 | lucena
# Processing Record 33 of Set 4 | port alfred
# Processing Record 34 of Set 4 | guerrero negro
# Processing Record 35 of Set 4 | gambo
# Processing Record 36 of Set 4 | bambous virieux
# Processing Record 37 of Set 4 | chlorakas
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | dicabisagan
# Processing Record 41 of Set 4 | amderma
# 'coord'
# Processing Record 42 of Set 4 | port hedland
# Processing Record 43 of Set 4 | hokitika
# Processing Record 44 of Set 4 | cockburn town
# Processing Record 45 of Set 4 | mogadishu
# Processing Record 46 of Set 4 | mackay
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | ust-tsilma
# Processing Record 2 of Set 5 | ilulissat
# Processing Record 3 of Set 5 | faro
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | suntar
# Processing Record 7 of Set 5 | bama
# Processing Record 8 of Set 5 | point pleasant
# Processing Record 9 of Set 5 | paray-le-monial
# Processing Record 10 of Set 5 | anaconda
# Processing Record 11 of Set 5 | old road
# 'coord'
# Processing Record 12 of Set 5 | skalistyy
# 'coord'
# Processing Record 13 of Set 5 | mys shmidta
# 'coord'
# Processing Record 14 of Set 5 | luau
# Processing Record 15 of Set 5 | bagojo
# Processing Record 16 of Set 5 | bataipora
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | henties bay
# Processing Record 19 of Set 5 | karaul
# 'coord'
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | gangotri
# 'coord'
# Processing Record 22 of Set 5 | raga
# Processing Record 23 of Set 5 | atar
# Processing Record 24 of Set 5 | jalalabad
# Processing Record 25 of Set 5 | udachnyy
# Processing Record 26 of Set 5 | kilindoni
# Processing Record 27 of Set 5 | flinders
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | chekhov
# Processing Record 30 of Set 5 | nouadhibou
# Processing Record 31 of Set 5 | general cepeda
# Processing Record 32 of Set 5 | indianola
# Processing Record 33 of Set 5 | san patricio
# Processing Record 34 of Set 5 | gopalpur
# Processing Record 35 of Set 5 | srednekolymsk
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | egvekinot
# Processing Record 38 of Set 5 | birpur
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | grezzana
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | gornyy
# Processing Record 44 of Set 5 | adolfo lopez mateos
# Processing Record 45 of Set 5 | kichera
# Processing Record 46 of Set 5 | camacha
# Processing Record 47 of Set 5 | ekhabi
# Processing Record 48 of Set 5 | urfa
# 'coord'
# Processing Record 49 of Set 5 | nyurba
# Processing Record 50 of Set 5 | bani walid
# Processing Record 1 of Set 6 | ambon
# Processing Record 2 of Set 6 | kokkola
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | kang
# Processing Record 5 of Set 6 | nikolskoye
# Processing Record 6 of Set 6 | siderno
# Processing Record 7 of Set 6 | mantua
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | hervey bay
# Processing Record 10 of Set 6 | havre-saint-pierre
# Processing Record 11 of Set 6 | puerto baquerizo moreno
# Processing Record 12 of Set 6 | leningradskiy
# Processing Record 13 of Set 6 | sawakin
# Processing Record 14 of Set 6 | khilok
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | namatanai
# Processing Record 17 of Set 6 | ostersund
# Processing Record 18 of Set 6 | vostok
# Processing Record 19 of Set 6 | black river
# Processing Record 20 of Set 6 | cap malheureux
# Processing Record 21 of Set 6 | tumannyy
# 'coord'
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | bonthe
# Processing Record 24 of Set 6 | lively
# Processing Record 25 of Set 6 | iralaya
# Processing Record 26 of Set 6 | barnova
# Processing Record 27 of Set 6 | verkhoyansk
# Processing Record 28 of Set 6 | solnechnyy
# Processing Record 29 of Set 6 | ossora
# Processing Record 30 of Set 6 | cervo
# Processing Record 31 of Set 6 | port elizabeth
# Processing Record 32 of Set 6 | saint-augustin
# Processing Record 33 of Set 6 | chengam
# Processing Record 34 of Set 6 | roma
# Processing Record 35 of Set 6 | cascais
# Processing Record 36 of Set 6 | avarua
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | celestun
# Processing Record 39 of Set 6 | santa clara
# Processing Record 40 of Set 6 | paro
# Processing Record 41 of Set 6 | pacifica
# Processing Record 42 of Set 6 | bikaner
# Processing Record 43 of Set 6 | stromness
# Processing Record 44 of Set 6 | frontignan
# Processing Record 45 of Set 6 | vao
# Processing Record 46 of Set 6 | sooke
# Processing Record 47 of Set 6 | cutro
# Processing Record 48 of Set 6 | codrington
# Processing Record 49 of Set 6 | tynset
# Processing Record 50 of Set 6 | lata
# Processing Record 1 of Set 7 | ulaangom
# Processing Record 2 of Set 7 | limon
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | kavieng
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | itacarambi
# Processing Record 7 of Set 7 | shelburne
# Processing Record 8 of Set 7 | verkhnevilyuysk
# Processing Record 9 of Set 7 | halalo
# 'coord'
# Processing Record 10 of Set 7 | yerbogachen
# Processing Record 11 of Set 7 | bargal
# 'coord'
# Processing Record 12 of Set 7 | diapaga
# Processing Record 13 of Set 7 | tongeren
# Processing Record 14 of Set 7 | kreminna
# Processing Record 15 of Set 7 | tateyama
# Processing Record 16 of Set 7 | constitucion
# Processing Record 17 of Set 7 | carballo
# Processing Record 18 of Set 7 | kudahuvadhoo
# Processing Record 19 of Set 7 | takoradi
# Processing Record 20 of Set 7 | williston
# Processing Record 21 of Set 7 | laguna
# Processing Record 22 of Set 7 | lensk
# Processing Record 23 of Set 7 | careiro da varzea
# Processing Record 24 of Set 7 | tupiza
# Processing Record 25 of Set 7 | emirdag
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | berkovica
# Processing Record 28 of Set 7 | lazaro cardenas
# Processing Record 29 of Set 7 | valparaiso
# Processing Record 30 of Set 7 | olafsvik
# Processing Record 31 of Set 7 | mali
# Processing Record 32 of Set 7 | canico
# Processing Record 33 of Set 7 | pombas
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | hukuntsi
# Processing Record 36 of Set 7 | beringovskiy
# Processing Record 37 of Set 7 | irbit
# Processing Record 38 of Set 7 | sentyabrskiy
# 'coord'
# Processing Record 39 of Set 7 | husavik
# Processing Record 40 of Set 7 | manavalakurichi
# Processing Record 41 of Set 7 | george
# Processing Record 42 of Set 7 | sept-iles
# Processing Record 43 of Set 7 | westport
# Processing Record 44 of Set 7 | aklavik
# Processing Record 45 of Set 7 | vanimo
# Processing Record 46 of Set 7 | kletskaya
# Processing Record 47 of Set 7 | togur
# Processing Record 48 of Set 7 | zhigansk
# Processing Record 49 of Set 7 | kuryk
# Processing Record 50 of Set 7 | barcelos
# Processing Record 1 of Set 8 | wulanhaote
# 'coord'
# Processing Record 2 of Set 8 | anapskaya
# Processing Record 3 of Set 8 | bubaque
# Processing Record 4 of Set 8 | ambovombe
# Processing Record 5 of Set 8 | parrita
# Processing Record 6 of Set 8 | marcona
# 'coord'
# Processing Record 7 of Set 8 | merauke
# Processing Record 8 of Set 8 | bath
# Processing Record 9 of Set 8 | quelimane
# Processing Record 10 of Set 8 | tungkang
# 'coord'
# Processing Record 11 of Set 8 | sidney
# Processing Record 12 of Set 8 | pingliang
# Processing Record 13 of Set 8 | alofi
# Processing Record 14 of Set 8 | madimba
# Processing Record 15 of Set 8 | kytlym
# 'coord'
# Processing Record 16 of Set 8 | kokopo
# Processing Record 17 of Set 8 | tromso
# Processing Record 18 of Set 8 | ardistan
# 'coord'
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | khandyga
# Processing Record 21 of Set 8 | porto novo
# Processing Record 22 of Set 8 | laiagam
# 'coord'
# Processing Record 23 of Set 8 | gamba
# Processing Record 24 of Set 8 | mbekenyera
# Processing Record 25 of Set 8 | mayo
# Processing Record 26 of Set 8 | prieska
# Processing Record 27 of Set 8 | adrar
# Processing Record 28 of Set 8 | imbituba
# Processing Record 29 of Set 8 | sorong
# Processing Record 30 of Set 8 | torbay
# Processing Record 31 of Set 8 | bucerias
# Processing Record 32 of Set 8 | ovre ardal
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | zhangye
# Processing Record 35 of Set 8 | banda aceh
# Processing Record 36 of Set 8 | khorramshahr
# Processing Record 37 of Set 8 | shetpe
# Processing Record 38 of Set 8 | lorengau
# Processing Record 39 of Set 8 | wagar
# Processing Record 40 of Set 8 | nelspruit
# Processing Record 41 of Set 8 | asyut
# Processing Record 42 of Set 8 | avera
# Processing Record 43 of Set 8 | marsh harbour
# Processing Record 44 of Set 8 | burgeo
# Processing Record 45 of Set 8 | puerto del rosario
# Processing Record 46 of Set 8 | vestmannaeyjar
# Processing Record 47 of Set 8 | coro
# Processing Record 48 of Set 8 | dubbo
# Processing Record 49 of Set 8 | katherine
# Processing Record 50 of Set 8 | valley city
# Processing Record 1 of Set 9 | iranshahr
# Processing Record 2 of Set 9 | mezen
# Processing Record 3 of Set 9 | bacuit
# 'coord'
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | guadalupe y calvo
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | toliary
# 'coord'
# Processing Record 8 of Set 9 | elat
# Processing Record 9 of Set 9 | soma
# Processing Record 10 of Set 9 | samusu
# 'coord'
# Processing Record 11 of Set 9 | east london
# Processing Record 12 of Set 9 | itoman
# Processing Record 13 of Set 9 | lac du bonnet
# Processing Record 14 of Set 9 | half moon bay
# Processing Record 15 of Set 9 | broken hill
# Processing Record 16 of Set 9 | salalah
# Processing Record 17 of Set 9 | mar del plata
# Processing Record 18 of Set 9 | severnoye
# Processing Record 19 of Set 9 | asau
# Processing Record 20 of Set 9 | raudeberg
# Processing Record 21 of Set 9 | mercedes
# Processing Record 22 of Set 9 | yeppoon
# Processing Record 23 of Set 9 | birjand
# Processing Record 24 of Set 9 | changli
# Processing Record 25 of Set 9 | nerang
# Processing Record 26 of Set 9 | lolua
# 'coord'
# Processing Record 27 of Set 9 | faya
# Processing Record 28 of Set 9 | bowen
# Processing Record 29 of Set 9 | haibowan
# 'coord'
# Processing Record 30 of Set 9 | kanigoro
# Processing Record 31 of Set 9 | samarai
# Processing Record 32 of Set 9 | nha trang
# Processing Record 33 of Set 9 | bathsheba
# Processing Record 34 of Set 9 | saldanha
# Processing Record 35 of Set 9 | krasnoye
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | benghazi
# Processing Record 38 of Set 9 | mubi
# Processing Record 39 of Set 9 | gubbio
# Processing Record 40 of Set 9 | maniitsoq
# Processing Record 41 of Set 9 | ballina
# Processing Record 42 of Set 9 | gediz
# Processing Record 43 of Set 9 | palmer
# Processing Record 44 of Set 9 | novyy urengoy
# Processing Record 45 of Set 9 | tumpat
# Processing Record 46 of Set 9 | anaco
# Processing Record 47 of Set 9 | sao filipe
# Processing Record 48 of Set 9 | grand baie
# Processing Record 49 of Set 9 | liku
# Processing Record 50 of Set 9 | lyuban
# Processing Record 1 of Set 10 | ngukurr
# 'coord'
# Processing Record 2 of Set 10 | esso
# Processing Record 3 of Set 10 | santa isabel do rio negro
# Processing Record 4 of Set 10 | warqla
# 'coord'
# Processing Record 5 of Set 10 | witu
# Processing Record 6 of Set 10 | wanning
# Processing Record 7 of Set 10 | evensk
# Processing Record 8 of Set 10 | victoria
# Processing Record 9 of Set 10 | les cayes
# Processing Record 10 of Set 10 | rincon
# Processing Record 11 of Set 10 | taoudenni
# Processing Record 12 of Set 10 | gizo
# Processing Record 13 of Set 10 | dukat
# Processing Record 14 of Set 10 | belmonte
# Processing Record 15 of Set 10 | kruisfontein
# Processing Record 16 of Set 10 | requena
# Processing Record 17 of Set 10 | rayon
# Processing Record 18 of Set 10 | malanje
# Processing Record 19 of Set 10 | aleksandrovsk
# Processing Record 20 of Set 10 | richards bay
# Processing Record 21 of Set 10 | kieta
# Processing Record 22 of Set 10 | lagoa
# Processing Record 23 of Set 10 | rongcheng
# Processing Record 24 of Set 10 | eureka
# Processing Record 25 of Set 10 | tiznit
# Processing Record 26 of Set 10 | okhotsk
# Processing Record 27 of Set 10 | taft
# Processing Record 28 of Set 10 | corinto
# Processing Record 29 of Set 10 | sacuieu
# 'coord'
# Processing Record 30 of Set 10 | port hardy
# Processing Record 31 of Set 10 | mokokchung
# Processing Record 32 of Set 10 | paita
# Processing Record 33 of Set 10 | clarence town
# Processing Record 34 of Set 10 | azimur
# 'coord'
# Processing Record 35 of Set 10 | saint-pierre
# Processing Record 36 of Set 10 | taltal
# Processing Record 37 of Set 10 | porkhov
# Processing Record 38 of Set 10 | bambui
# Processing Record 39 of Set 10 | gimli
# Processing Record 40 of Set 10 | alta floresta
# Processing Record 41 of Set 10 | murdochville
# Processing Record 42 of Set 10 | taburi
# 'coord'
# Processing Record 43 of Set 10 | dzhusaly
# 'coord'
# Processing Record 44 of Set 10 | dunedin
# Processing Record 45 of Set 10 | mandan
# Processing Record 46 of Set 10 | kloulklubed
# Processing Record 47 of Set 10 | haimen
# Processing Record 48 of Set 10 | puerto colombia
# Processing Record 49 of Set 10 | wajir
# Processing Record 50 of Set 10 | de aar
# Processing Record 1 of Set 11 | torbat-e jam
# Processing Record 2 of Set 11 | teeli
# Processing Record 3 of Set 11 | soldotna
# Processing Record 4 of Set 11 | daru
# Processing Record 5 of Set 11 | akim swedru
# Processing Record 6 of Set 11 | nueve de julio
# Processing Record 7 of Set 11 | koshurnikovo
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | beroroha
# Processing Record 10 of Set 11 | bintulu
# Processing Record 11 of Set 11 | tuskegee
# Processing Record 12 of Set 11 | shimoda
# Processing Record 13 of Set 11 | klyuchi
# Processing Record 14 of Set 11 | son la
# Processing Record 15 of Set 11 | port lincoln
# Processing Record 16 of Set 11 | matagami
# Processing Record 17 of Set 11 | camopi
# Processing Record 18 of Set 11 | mullaitivu
# 'coord'
# Processing Record 19 of Set 11 | lima
# Processing Record 20 of Set 11 | ayan
# Processing Record 21 of Set 11 | buala
# Processing Record 22 of Set 11 | qaqortoq
# Processing Record 23 of Set 11 | tabuk
# Processing Record 24 of Set 11 | la orilla
# Processing Record 25 of Set 11 | tignere
# Processing Record 26 of Set 11 | kharp
# Processing Record 27 of Set 11 | bafq
# Processing Record 28 of Set 11 | fortuna
# Processing Record 29 of Set 11 | manuk mangkaw
# Processing Record 30 of Set 11 | yar-sale
# Processing Record 31 of Set 11 | stornoway
# Processing Record 32 of Set 11 | ewa beach
# Processing Record 33 of Set 11 | vila do maio
# Processing Record 34 of Set 11 | suluq
# Processing Record 35 of Set 11 | pangoa
# Processing Record 36 of Set 11 | lalibela
# Processing Record 37 of Set 11 | leshukonskoye
# Processing Record 38 of Set 11 | abu kamal
# Processing Record 39 of Set 11 | normandin
# Processing Record 40 of Set 11 | manzhouli
# Processing Record 41 of Set 11 | tigil
# Processing Record 42 of Set 11 | sambava
# Processing Record 43 of Set 11 | rio grande
# Processing Record 44 of Set 11 | umm lajj
# Processing Record 45 of Set 11 | phan rang
# 'coord'
# Processing Record 46 of Set 11 | roald
# Processing Record 47 of Set 11 | tenenkou
# Processing Record 48 of Set 11 | hendijan
# 'coord'
# Processing Record 49 of Set 11 | ilanskiy
# Processing Record 50 of Set 11 | amapa
# Processing Record 1 of Set 12 | arman
# Processing Record 2 of Set 12 | millinocket
# Processing Record 3 of Set 12 | helong
# Processing Record 4 of Set 12 | tzucacab
# Processing Record 5 of Set 12 | caravelas
# Processing Record 6 of Set 12 | bayir
# Processing Record 7 of Set 12 | rulenge
# Processing Record 8 of Set 12 | mitu
# Processing Record 9 of Set 12 | methoni
# Processing Record 10 of Set 12 | bodden town
# Processing Record 11 of Set 12 | ahipara
# Processing Record 12 of Set 12 | esil
# Processing Record 13 of Set 12 | kalmar
# Processing Record 14 of Set 12 | beihai
# Processing Record 15 of Set 12 | port moresby
# Processing Record 16 of Set 12 | seybaplaya
# Processing Record 17 of Set 12 | obihiro
# Processing Record 18 of Set 12 | bac lieu
# Processing Record 19 of Set 12 | kalemie
# Processing Record 20 of Set 12 | koumac
# Processing Record 21 of Set 12 | mwinilunga
# Processing Record 22 of Set 12 | pathein
# Processing Record 23 of Set 12 | bjornevatn
# Processing Record 24 of Set 12 | maralal
# Processing Record 25 of Set 12 | nome
# Processing Record 26 of Set 12 | svetlogorsk
# Processing Record 27 of Set 12 | sovetskiy
# Processing Record 28 of Set 12 | attawapiskat
# 'coord'
# Processing Record 29 of Set 12 | veraval
# Processing Record 30 of Set 12 | borba
# Processing Record 31 of Set 12 | chunskiy
# Processing Record 32 of Set 12 | sao joao da barra
# Processing Record 33 of Set 12 | buta
# Processing Record 34 of Set 12 | axim
# Processing Record 35 of Set 12 | corpus christi
# Processing Record 36 of Set 12 | vila franca do campo
# Processing Record 37 of Set 12 | hwange
# Processing Record 38 of Set 12 | mazyr
# Processing Record 39 of Set 12 | bannawag
# 'coord'
# Processing Record 40 of Set 12 | corum
# Processing Record 41 of Set 12 | biltine
# Processing Record 42 of Set 12 | moorhead
# Processing Record 43 of Set 12 | cooma
# Processing Record 44 of Set 12 | usinsk
# Processing Record 45 of Set 12 | grand gaube
# Processing Record 46 of Set 12 | kupang
# Processing Record 47 of Set 12 | moron
# Processing Record 48 of Set 12 | chongwe
# Processing Record 49 of Set 12 | ulaanbaatar
# Processing Record 50 of Set 12 | izumo
# Processing Record 1 of Set 13 | invermere
# Processing Record 2 of Set 13 | edson
# Processing Record 3 of Set 13 | ashland
# Processing Record 4 of Set 13 | tocopilla
# Processing Record 5 of Set 13 | waipawa
# Processing Record 6 of Set 13 | escuinapa
# Processing Record 7 of Set 13 | panguna
# Processing Record 8 of Set 13 | aquiraz
# Processing Record 9 of Set 13 | bilma
# Processing Record 10 of Set 13 | rafaela
# Processing Record 11 of Set 13 | kavaratti
# Processing Record 12 of Set 13 | sharan
# Processing Record 13 of Set 13 | ende
# Processing Record 14 of Set 13 | nishihara
# Processing Record 15 of Set 13 | shunyi
# Processing Record 16 of Set 13 | elbrus
# Processing Record 17 of Set 13 | isla mujeres
# Processing Record 18 of Set 13 | xai-xai
# Processing Record 19 of Set 13 | windsor
# Processing Record 20 of Set 13 | shangzhi
# Processing Record 21 of Set 13 | morehead
# Processing Record 22 of Set 13 | auki
# Processing Record 23 of Set 13 | sydney
# Processing Record 24 of Set 13 | manaure
# Processing Record 25 of Set 13 | bradenton
# Processing Record 26 of Set 13 | chincha alta
# Processing Record 27 of Set 13 | mount isa
# Processing Record 28 of Set 13 | sur
# Processing Record 29 of Set 13 | maarianhamina
# Processing Record 30 of Set 13 | akureyri
# Processing Record 31 of Set 13 | knysna
# Processing Record 32 of Set 13 | geeste
# Processing Record 33 of Set 13 | uppsala
# Processing Record 34 of Set 13 | halifax
# Processing Record 35 of Set 13 | korostyshiv
# Processing Record 36 of Set 13 | mana
# Processing Record 37 of Set 13 | deogarh
# Processing Record 38 of Set 13 | koslan
# Processing Record 39 of Set 13 | waingapu
# Processing Record 40 of Set 13 | kapiri mposhi
# Processing Record 41 of Set 13 | nara
# Processing Record 42 of Set 13 | mnogovershinnyy
# Processing Record 43 of Set 13 | fochabers
# Processing Record 44 of Set 13 | saint-prosper
# Processing Record 45 of Set 13 | zhuhai
# Processing Record 46 of Set 13 | soyo
# Processing Record 47 of Set 13 | ereymentau
# Processing Record 48 of Set 13 | vilcun
# Processing Record 49 of Set 13 | coachella
# Processing Record 50 of Set 13 | sola
# Processing Record 1 of Set 14 | xianyang
# Processing Record 2 of Set 14 | clyde river
# Processing Record 3 of Set 14 | joshimath
# Processing Record 4 of Set 14 | molochnoye
# Processing Record 5 of Set 14 | darhan
# Processing Record 6 of Set 14 | coxim
# Processing Record 7 of Set 14 | linhares
# Processing Record 8 of Set 14 | saurimo
# Processing Record 9 of Set 14 | ahuimanu
# Processing Record 10 of Set 14 | mahanoro
# Processing Record 11 of Set 14 | bara
# Processing Record 12 of Set 14 | wanaka
# Processing Record 13 of Set 14 | havoysund
# Processing Record 14 of Set 14 | meulaboh
# Processing Record 15 of Set 14 | altoona
# Processing Record 16 of Set 14 | log
# Processing Record 17 of Set 14 | mizdah
# Processing Record 18 of Set 14 | alushta
# Processing Record 19 of Set 14 | nan
# Processing Record 20 of Set 14 | cardedeu
# Processing Record 21 of Set 14 | saint anthony
# Processing Record 22 of Set 14 | tera
# Processing Record 23 of Set 14 | gazanjyk
# Processing Record 24 of Set 14 | spalding
# Processing Record 25 of Set 14 | anadyr
# Processing Record 26 of Set 14 | naze
# Processing Record 27 of Set 14 | kondinskoye
# Processing Record 28 of Set 14 | umba
# Processing Record 29 of Set 14 | fier
# Processing Record 30 of Set 14 | makakilo city
# Processing Record 31 of Set 14 | shingu
# Processing Record 32 of Set 14 | ziarat
# Processing Record 33 of Set 14 | broome
# Processing Record 34 of Set 14 | hualmay
# Processing Record 35 of Set 14 | ribeirao do pinhal
# 'coord'
# Processing Record 36 of Set 14 | marv dasht
# 'coord'
# Processing Record 37 of Set 14 | remedios
# Processing Record 38 of Set 14 | sikasso
# Processing Record 39 of Set 14 | baruun-urt
# Processing Record 40 of Set 14 | lashio
# Processing Record 41 of Set 14 | ardakan
# Processing Record 42 of Set 14 | shache
# Processing Record 43 of Set 14 | sulangan
# Processing Record 44 of Set 14 | puerto narino
# Processing Record 45 of Set 14 | road town
# Processing Record 46 of Set 14 | touros
# Processing Record 47 of Set 14 | abapo
# Processing Record 48 of Set 14 | pahrump
# Processing Record 49 of Set 14 | gazojak
# Processing Record 50 of Set 14 | mikumi
# Processing Record 1 of Set 15 | svetlaya
# Processing Record 2 of Set 15 | angoche
# Processing Record 3 of Set 15 | surt
# Processing Record 4 of Set 15 | mandera
# Processing Record 5 of Set 15 | dombarovskiy
# Processing Record 6 of Set 15 | chinsali
# Processing Record 7 of Set 15 | novo aripuana
# Processing Record 8 of Set 15 | kirakira
# Processing Record 9 of Set 15 | sohbatpur
# Processing Record 10 of Set 15 | sovik
# Processing Record 11 of Set 15 | bundaberg
# Processing Record 12 of Set 15 | megion
# Processing Record 13 of Set 15 | farkhor
# Processing Record 14 of Set 15 | samalaeulu
# 'coord'
# Processing Record 15 of Set 15 | mgandu
# Processing Record 16 of Set 15 | huangchuan
# Processing Record 17 of Set 15 | omboue
# Processing Record 18 of Set 15 | kadykchan
# 'coord'
# Processing Record 19 of Set 15 | swan river
# Processing Record 20 of Set 15 | roblin
# Processing Record 21 of Set 15 | southbridge
# Processing Record 22 of Set 15 | monticello
# Processing Record 23 of Set 15 | bima
# Processing Record 24 of Set 15 | silvassa
# Processing Record 25 of Set 15 | soe
# Processing Record 26 of Set 15 | cockburn harbour
# 'coord'
# Processing Record 27 of Set 15 | ust-kuyga
# Processing Record 28 of Set 15 | oudtshoorn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0     Tasiilaq  65.6145  -37.6368     overcast clouds     30.36        78
# 1       Pangai -19.8000 -174.3500       broken clouds     82.51        65
# 2       Dingle  10.9995  122.6711     overcast clouds     74.32        87
# 3         Lebu -37.6167  -73.6500           clear sky     61.92        77
# 4    Coihaique -45.5752  -72.0662           clear sky     78.66        37
# 5      Mataura -46.1927  168.8643           clear sky     61.48        49
# 6  Songjianghe  42.1859  127.4790    scattered clouds     11.37        95
# 7    Cape Town -33.9258   18.4232           clear sky     62.10        69
# 8   Chokurdakh  70.6333  147.9167     overcast clouds    -23.46        97
# 9    Osterburg  52.7833   11.7667     overcast clouds     34.50        83
#
#    Cloudiness  Wind Speed Country                 Date
# 0          98        8.88      GL  2021-12-06 22:05:03
# 1          75       10.36      TO  2021-12-06 22:05:14
# 2          96        5.06      PH  2021-12-06 22:05:15
# 3           3       13.47      CL  2021-12-06 22:08:28
# 4           7        6.76      CL  2021-12-06 22:01:26
# 5           4        3.44      NZ  2021-12-06 22:05:16
# 6          41        3.06      CN  2021-12-06 22:05:16
# 7           2        3.00      ZA  2021-12-06 22:05:16
# 8         100        2.17      RU  2021-12-06 22:05:17
# 9         100        9.51      DE  2021-12-06 22:05:17

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tasiilaq      GL  65.6145  -37.6368     30.36        78          98
# 1       Pangai      TO -19.8000 -174.3500     82.51        65          75
# 2       Dingle      PH  10.9995  122.6711     74.32        87          96
# 3         Lebu      CL -37.6167  -73.6500     61.92        77           3
# 4    Coihaique      CL -45.5752  -72.0662     78.66        37           7
# 5      Mataura      NZ -46.1927  168.8643     61.48        49           4
# 6  Songjianghe      CN  42.1859  127.4790     11.37        95          41
# 7    Cape Town      ZA -33.9258   18.4232     62.10        69           2
# 8   Chokurdakh      RU  70.6333  147.9167    -23.46        97         100
# 9    Osterburg      DE  52.7833   11.7667     34.50        83         100
#
#    Wind Speed Current Description
# 0        8.88     overcast clouds
# 1       10.36       broken clouds
# 2        5.06     overcast clouds
# 3       13.47           clear sky
# 4        6.76           clear sky
# 5        3.44           clear sky
# 6        3.06    scattered clouds
# 7        3.00           clear sky
# 8        2.17     overcast clouds
# 9        9.51     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
